# %%
#PROBLEM 1
# WHEN PAPER IS FOLDED 43 times
THICKNESS = 0.00008
folded_thickness = THICKNESS *2**43
print("Thickness: {} meters".format(folded_thickness))
# Out:
# Thickness: 703687441.77664 meters

# %%
#PROBLEM 2
#convert meters to kilometers and diplaying with two decimal places
print("Thickness: {: .2f} kilometers".format(folded_thickness / 10000))
# Out:
# Thickness:  70368.74 kilometers

# %%
#PROBLME 3
#create using a for statement
thickness = 0.00008
folded_thickness = 0.00008*2
for i in range (1,43):
    folded_thickness = folded_thickness*2
print("Thickness: {: .2f} kilometers".format(folded_thickness / 10000))
# Out:
# Thickness:  70368.74 kilometers

# %%
#PROBLEM 4
#Comparison of calculation time
import time
start = time.time()
THICKNESS = 0.00008
folded_thickness = THICKNESS *2**43
elapsed_time = time.time() - start
print("time : {}[s]".format(elapsed_time))
# Out:
# time : 0.0[s]

# %%
# %%timeit
THICKNESS = 0.00008
folded_thickness = THICKNESS *2**43
# Out:
# 91.8 ns ± 0.442 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
# %%timeit
thickness = 0.00008
folded_thickness = 0.00008*2
for i in range (1,43):
    folded_thickness = folded_thickness*2
# Out:
# 2.06 µs ± 16.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
#PROBLEM 5
#saving to a list
mylist = []
thickness = 0.00008
folded_thickness = thickness*2
mylist.append(thickness)
mylist.append(folded_thickness)
for i in range (1,43):
    folded_thickness = folded_thickness*2
    mylist.append(folded_thickness)
len(mylist)
# Out:
# 44

# %%
#PROBLEM 6
#Displaying a line graph
import matplotlib.pyplot as plt
# %matplotlib inline
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(mylist)
plt.show()
#thickness in becomes thicker as the folds keeps on folding

# %%
#PROBLEM 7
#customizing graphs
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(mylist, color='green', linestyle='dotted', linewidth=3)
plt.show()

# %%
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(mylist, color='blue', linewidth=4)
plt.show()

# %%
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(mylist, color='red', linewidth=4)
plt.tick_params(labelsize=20)
plt.show()
